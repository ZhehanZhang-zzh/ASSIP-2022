# %%
import json
import pandas as pd
pd.__version__
# Out:
# '1.3.5'

# %%
videos = {}

with open('../data_csv/072622_samples/game_channel_videos.json') as json_file:
    data = json.load(json_file)

    for key in data:
        print(key)
        
        i=0
        
        for value in data[key]:
            for v in value:
                videos[i] = v
                i=i+1
# Out:
# UUtDTO_RQr8wf_lhvcPWvUgQ
# UUQldhsqGcoJuyqU-26cvcjQ
# UUvPmBM2wOVz8h6EVBoY6N3g
# UUZIuYUzkmEXgSSXzReOmeLw
# UUK04gsRst4_Lt5ZSpWZ6EaA
# UUKUcJOz32cYBjtHC0I7oZSw
# UUPHsU6YYKOOGJccT9qphGhA
# UUlh5azhOaKzdlThQFgoq-tw
# UUpFcHE36IoySjYj1Rytxyog
# UUIavp7_lYfUdwgbelK-Coog
# UUVlhlGM5b9qTbEF21I43u_A
# UUtYjgB1j48oFkneJ6VS6KUQ
# UU0QvI6XrcHsCOnYcT7n2LVw
# UU-sjC5fKKsrpcZRJwlZJzZQ
# UUSf0s2ogUVYpJPuzW1zpAOg
# UUuQqK0Br7BARWNCwzXdDkRw
# UULEx7nDvlDbby1JMrpNiyjg
# UU7ym_TycBuUsCZVhguovu7w
# UUYc_-FTKR77KR8q4SVFTVWQ
# UUs1HcDiXFdZ24hWdTczj6Wg
# UUFWTukSe71OIz00ApKJbEtw
# UUPjSGvIjI6X5eKFfzBhFSBQ
# UU7wsGCxsV8q6AzEnGdTW6Jg
# UUp-bonV8pbLO9tnuCl2BJ2w
# UUj4I9NfO3xIvl-Ym2Qzib1Q
# UUwV_0HmQkRrTcrReaMxPeDw
# UUOR8JcMRg_cFKx0etV5zXBQ
# UULEsipUKnZpQnGDJ1Dpk6wg
# UUK6-5owv4dGOMHMO--rCafA
# UUVmiN4HMG9sc4Em5F0jGR_A
# UU6u4spnoeIUHtfUZxhG2RfQ
# UUiK9wDWq98-JYOU4bM1xcBw
# UUCPK5LkmtBpvYu1UafCuh1g
# UU9YydG57epLqxA9cTzZXSeQ
# UUItxUF4G50Z1DyRBIztFaTw
# UU9UJfyhbPdmdVh2Y81JKUAA
# UUo_YEhQp_o8k6bxUxyWzJ8g
# ...

# %%
df = pd.json_normalize(videos.values())
df.to_csv("game_all_videos.csv", index=False)

# %%
df
# Out:
#                 kind                         etag           id  \
# 0      youtube#video  SBVlhRRkMxr7xRtEHsu9EifKABg  wmwSgd1v74Y
# 1      youtube#video  hDMBZ7TTpA0i1ymF15r8MJnkvm4  e8b1tZhRzeg
# 2      youtube#video  xcXVoRKxcHXduGmEbGTfelCclBM  cZCp0kHtcUQ
# 3      youtube#video  7_CUoFU-nbGscqEtON9xL7Ay6Go  H_7i4GHU_Ao
# 4      youtube#video  syGPFdDiTBZIXPjdtqo7G0HrYgc  mOiqnyPl2po
# ...              ...                          ...          ...
# 10048  youtube#video  scpy15iCqUB14kKsubDPDWs8yJ4  XQOO69vRIwU
# 10049  youtube#video  h3e6pvBAUnjNtoqUQh1jVlge9U4  JeVdNbSHdBQ
# 10050  youtube#video  _iamzTR4uPsFAY-CRR8jdDUtdAg  Td2GW8vFhoo
# 10051  youtube#video  X3H-gxXGJTAyIXYs-j6JGMGAUng  iV9vVLLLHPo
# 10052  youtube#video  967TYvCdi7NxIOzQQ3SVhmAsjW0  XblHv3wKWfw
#
#         snippet.publishedAt         snippet.channelId  \
# 0      2022-07-26T22:19:59Z  UCRAFUyShx5H3e2FO6HrwXYw
# 1      2022-07-23T14:30:15Z  UCRAFUyShx5H3e2FO6HrwXYw
# ...
