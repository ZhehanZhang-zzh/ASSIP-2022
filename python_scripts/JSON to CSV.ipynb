# %%
import json
import pandas as pd

data = read_json("videos.json")
pd.json_normalize(data.values())

# %%
# Out:
#             kind                         etag           id  \
# 0  youtube#video  gYrVGVqgnpPS0DmvkS-sngUMXuM  vCL2Inb7iwk
# 1  youtube#video  aRdv2P_bZnc-eQ8IwPhhBGJnkok  il_MaXXl8Iw
# 2  youtube#video  UfiW2WQbKNyZ84kQVgQkcSW_MYQ  c6lU-xYRjFA
# 3  youtube#video  iFYRV5YZ4wI5DiX-MH1wCkpae60  ma67yOdMQfs
# 4  youtube#video  PhbV6AdCVTaS9T47xaL9Lz16jSE  eSWST13stO4
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2022-07-05T23:46:47Z  UCsXYYt9hmwvaIl6v73JHKWw
# 1  2022-07-04T19:00:24Z  UCo_q6aOlvPH7M-j_XGWVgXg
# 2  2022-03-28T18:58:35Z  UC--3c8RqSfAqYBdDjIG3UNA
# 3  2021-01-23T17:00:15Z  UC--3c8RqSfAqYBdDjIG3UNA
# 4  2022-03-27T15:00:32Z  UCVo06dBGK9VBBhq15wJxZHQ
#
#                                        snippet.title  \
# 0          Is Surfing Malibu Worth the Crowd Factor?
# 1  PIPELINE - BIGGEST AND BEST WIPEOUTS!! WINTER ...
# 2  The World Loves Surfing | Best Of Red Bull Sur...
# 3  These Were The All-Time Surfing Moments Of The...
# ...
