# %%
import json
import pandas as pd

# %%
# Read the JSON file as python dictionary
data = pd.read_json("videos.json", orient='index')
data.head()
# Out:
#             kind                         etag           id  \
# 0  youtube#video  gYrVGVqgnpPS0DmvkS-sngUMXuM  vCL2Inb7iwk
# 1  youtube#video  aRdv2P_bZnc-eQ8IwPhhBGJnkok  il_MaXXl8Iw
# 2  youtube#video  UfiW2WQbKNyZ84kQVgQkcSW_MYQ  c6lU-xYRjFA
# 3  youtube#video  iFYRV5YZ4wI5DiX-MH1wCkpae60  ma67yOdMQfs
# 4  youtube#video  PhbV6AdCVTaS9T47xaL9Lz16jSE  eSWST13stO4
#
#                                              snippet  \
# 0  {'publishedAt': '2022-07-05T23:46:47Z', 'chann...
# 1  {'publishedAt': '2022-07-04T19:00:24Z', 'chann...
# 2  {'publishedAt': '2022-03-28T18:58:35Z', 'chann...
# 3  {'publishedAt': '2021-01-23T17:00:15Z', 'chann...
# 4  {'publishedAt': '2022-03-27T15:00:32Z', 'chann...
#
#                                       contentDetails  \
# 0  {'duration': 'PT11M4S', 'dimension': '2d', 'de...
# 1  {'duration': 'PT18M22S', 'dimension': '2d', 'd...
# 2  {'duration': 'PT9M43S', 'dimension': '2d', 'de...
# 3  {'duration': 'PT6M2S', 'dimension': '2d', 'def...
# ...
