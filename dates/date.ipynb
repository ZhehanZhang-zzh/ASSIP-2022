# %%
import datetime
import csv
import pandas as pd
#date = '2021-05-21 11:22:03'
#10/16/2019 17:32
dates = {}
i=0

# %%
data = pd.read_csv('beauty_all_videos.csv', low_memory=False)
display(data.head())
# Out:
#             kind                         etag           id              date  \
# 0  youtube#video  uDVWrEZxZa4qFGbUd1lE10O9XrM  1Z9JSDd2a6E  10/16/2019 17:32
# 1  youtube#video  YADtsVqcNspksOL_Jt7pHqqbf08  C786JaFZ3OM   10/7/2019 23:22
# 2  youtube#video  _CwgRAgAS6oUrFlQQDesavSfkbc  RXo6hP9MfXc   9/27/2019 15:57
# 3  youtube#video  oME3bQYlNfSu9dIgVJAgHz8qQwU  y10uRxi4FmI   9/22/2019 15:50
# 4  youtube#video  R2wP9GIufgTUKnWZTYC_C9vAsvs  PbJ14Io6754   9/17/2019 12:31
#
#           snippet.channelId  \
# 0  UCBr9kNjpq5-hi9eF9nYvmwA
# 1  UCBr9kNjpq5-hi9eF9nYvmwA
# 2  UCBr9kNjpq5-hi9eF9nYvmwA
# 3  UCBr9kNjpq5-hi9eF9nYvmwA
# 4  UCBr9kNjpq5-hi9eF9nYvmwA
#
#                                        snippet.title  \
# 0  Recreating Cute Pinterest Fall Outfits (from m...
# 1    Jeans You Need This Fall (Affordable Mom Jeans)
# 2  TESTING NEW MAKEUP AT THE DRUGSTORE ... Blown ...
# 3              MY FIRST APARTMENT (TOUR) & GRWM VLOG
# 4                          WHAT I BOUGHT AT THE MALL
#
# ...

# %%
data['date'] = pd.to_datetime(data.date, infer_datetime_format = True)
display(data.head())
# Out:
#                 kind                         etag           id  \
# 11846  youtube#video  KF4MzIi_6k8F5J8XbpkmlGUacfU  3PrRxXZmZyQ
# 11845  youtube#video  tyrira6sto8N4Kxi2BjT_7MvePU  wH8dgeMoud0
# 11844  youtube#video  cWBJJUAvTA9bBPC2Qgb6xWuGsls  _gZQsmuX90U
# 11843  youtube#video  Azesgk1XSPzNQeZs_8Ol90sr7k0  MYzjRP8FiQE
# 11842  youtube#video  dDb9JOmsB8JQxdXMIIz8Y3JNQ0M  Eys2soQoW00
#
#                      date         snippet.channelId  \
# 11846 2007-11-14 03:17:00  UCtC8m_F7jX2fGOQ3_nomg4g
# 11845 2008-01-28 15:33:00  UCtC8m_F7jX2fGOQ3_nomg4g
# 11844 2008-01-29 01:37:00  UCtC8m_F7jX2fGOQ3_nomg4g
# 11843 2008-02-05 00:18:00  UCtC8m_F7jX2fGOQ3_nomg4g
# 11842 2008-02-05 01:44:00  UCtC8m_F7jX2fGOQ3_nomg4g
#
#                              snippet.title  \
# 11846                     ELF Brush Review
# 11845  3 Makeup Items I Can't Live Without
# 11844             What's in My Makeup Bag?
# 11843                    Eye Makeup How-To
# 11842               Liquid Eyeliner Review
#
# ...

# %%
data.sort_values(by = 'date', ascending = True, inplace = True)
display(data.head())
# Out:
#                 kind                         etag           id  \
# 11846  youtube#video  KF4MzIi_6k8F5J8XbpkmlGUacfU  3PrRxXZmZyQ
# 11845  youtube#video  tyrira6sto8N4Kxi2BjT_7MvePU  wH8dgeMoud0
# 11844  youtube#video  cWBJJUAvTA9bBPC2Qgb6xWuGsls  _gZQsmuX90U
# 11843  youtube#video  Azesgk1XSPzNQeZs_8Ol90sr7k0  MYzjRP8FiQE
# 11842  youtube#video  dDb9JOmsB8JQxdXMIIz8Y3JNQ0M  Eys2soQoW00
#
#                      date         snippet.channelId  \
# 11846 2007-11-14 03:17:00  UCtC8m_F7jX2fGOQ3_nomg4g
# 11845 2008-01-28 15:33:00  UCtC8m_F7jX2fGOQ3_nomg4g
# 11844 2008-01-29 01:37:00  UCtC8m_F7jX2fGOQ3_nomg4g
# 11843 2008-02-05 00:18:00  UCtC8m_F7jX2fGOQ3_nomg4g
# 11842 2008-02-05 01:44:00  UCtC8m_F7jX2fGOQ3_nomg4g
#
#                              snippet.title  \
# 11846                     ELF Brush Review
# 11845  3 Makeup Items I Can't Live Without
# 11844             What's in My Makeup Bag?
# 11843                    Eye Makeup How-To
# 11842               Liquid Eyeliner Review
#
# ...

# %%
display(data.tail())
# Out:
#                 kind                         etag           id  \
# 41955  youtube#video  5SYt7weka6YGWFqECPNYQV5z4qk  99WXWZXPKO4
# 41956  youtube#video  CYdabR3f-YZhewqHlDN-ZiVQ1n4  NhqxswLb3RM
# 41957  youtube#video  BsT3BzaJ2BkXGWJa3LNH-ttquo4  fMwLcQfBQj0
# 41958  youtube#video  KfvqLvq1uofBfWZxIgjuOfN8HK8  qccI1ZuJC70
# 41959  youtube#video  xFyottsKPRQjfaZKdJA1dBnjmwE  xqCEb8j0Ado
#
#                    date         snippet.channelId  \
# 41955  12/30/2019 10:32  UC3SOAjr_P7jqv9VDIrXo2RQ
# 41956   12/23/2019 6:50  UC3SOAjr_P7jqv9VDIrXo2RQ
# 41957   12/16/2019 2:36  UC3SOAjr_P7jqv9VDIrXo2RQ
# 41958    12/7/2019 1:40  UC3SOAjr_P7jqv9VDIrXo2RQ
# 41959    12/2/2019 2:27  UC3SOAjr_P7jqv9VDIrXo2RQ
#
#                                            snippet.title  \
# 41955  MY FIRST SEAFOOD BOIL WITH THE FAM MUKBANG STY...
# 41956  BEST IN BEAUTY 2019 PRODUCTS I'VE TRIED AND LO...
# 41957            GOING THROUGH MY HAIR PRODUCT EMPTIES!!
# ...
